# %% [markdown]
# # Transfer learning approach

# %% [markdown]
# ## Data exploration

# %%
from pathlib import Path

DATA_DIR = Path("/root/data/GDSC/data/data_small")

# %%
audio_paths = list(DATA_DIR.glob("train/*.wav"))

# %%
example_audio_path = audio_paths[0]
print(example_audio_path)
# Out:
# /root/data/GDSC/data/data_small/train/Diceroproctaeugraphica_GBIF3415492691_IN83523175_259387.wav

# %%
import librosa

y, sampling_rate = librosa.load(example_audio_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_mel_spectrogram(S: np.ndarray, sampling_rate: float) -> None:
    fig, ax = plt.subplots()
    
    # Actual rendering
    S_db = librosa.power_to_db(S, ref=np.max)
    img = librosa.display.specshow(S_db, x_axis="time", y_axis="mel", sr=sampling_rate, ax=ax)
    
    # Image formatting
    fig.colorbar(img, ax=ax, format="%+2.f dB")
    ax.set(title='Mel-frequency spectrogram')
    
    fig.show()

# %%
S = librosa.feature.melspectrogram(y=y, sr=sampling_rate)
plot_mel_spectrogram(S, sampling_rate)
